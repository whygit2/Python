# %% [markdown]
# Write program to Enter Name and Percentage Marks in a dictionary and display information on screen.

# %%
student = {}
student['Name'] = input("Enter Name: ")
student['Percentage'] = float(input("Enter Percentage Marks: "))

print("\nStudent Information")
for key, value in student.items():
    print(f"{key}: {value}")

print(student)
# Out:
# Student Information
# Name: Amit
# Percentage: 70.0
# {'Name': 'Amit', 'Percentage': 70.0}

# %% [markdown]
# Write a program to find number of occurrence of each letter present in the given string .

# %%
string = input("Enter a string: ")
freq = {}

for char in string:
    if char.isalpha():
        char = char.lower()
        freq[char] = freq.get(char, 0) + 1

print("\n--- Letter Frequency ---")
for letter, count in sorted(freq.items()):
    print(f"{letter}: {count}")
print(freq)
# Out:
# --- Letter Frequency ---
# a: 1
# b: 1
# e: 1
# l: 2
# m: 1
# r: 1
# u: 1
# {'u': 1, 'm': 1, 'b': 1, 'r': 1, 'e': 1, 'l': 2, 'a': 1}

# %% [markdown]
# Write a program to find number of occurrence of each vowel present in the given string.

# %%
string = input("Enter a string: ").lower()
vowels = "aeiou"
freq = {v: 0 for v in vowels}

for char in string:
    if char in vowels:
        freq[char] += 1

print("\n--- Vowel Frequency ---")
for vowel, count in freq.items():
    print(f"{vowel}: {count}")
print(freq)
# Out:
# --- Vowel Frequency ---
# a: 1
# e: 1
# i: 0
# o: 0
# u: 0
# {'a': 1, 'e': 1, 'i': 0, 'o': 0, 'u': 0}

# %% [markdown]
# Write a program to accept student names and marks from keyboard and creates as dictionary.
#        Also display student marks by taking student name as input.

# %%
students = {}

n = int(input("Enter number of students: "))
for i in range(n):
    name = input(f"Enter name of student {i+1}: ")
    marks = float(input(f"Enter marks of {name}: "))
    students[name] = marks

# Display marks by taking student name as input
search_name = input("\nEnter student name to check marks: ")
if search_name in students:
    print(f"{search_name}'s marks: {students[search_name]}")
else:
    print("Student not found!")

print("\n--- All Student Records ---")
for name, marks in students.items():
    print(f"{name}: {marks}")
# Out:
# Amit's marks: 88.0
#
# --- All Student Records ---
# Amit: 88.0
# Bob: 80.0
# Chrom: 99.0

# %%
print(f"{'Property':<22}{'List':<12}{'Tuple':<12}{'Set':<12}{'Frozenset':<12}{'Dictionary':<12}")
print("-" * 90)

rows = [
    ("Syntax",              "[ ]",       "( )",       "{ }",             "frozenset()",     "{ : }"),
    ("Ordered",             "Yes",       "Yes",       "No",              "No",               "Yes"),
    ("Mutable",             "Yes",       "No",        "Yes",             "No",               "Yes"),
    ("Allow Duplicates",    "Yes",       "Yes",       "No",              "No",               "No (keys)"),
    ("Indexed",             "Yes",       "Yes",       "No",              "No",               "No (key-based)"),
    ("Hetrogeneneous",      "Yes",       "Yes",       "Yes",             "Yes",              "Yes"),
    ("Hashable",            "No",        "Yes",       "No",              "Yes",              "No"),
    ("Can be dictionary key","No",       "Yes",       "No",              "Yes",              "No"),
    ("Can be nested",       "Yes",       "Yes",       "No",              "No",               "Yes"),
    ("Supports slicing",    "Yes",       "Yes",       "No",              "No",               "No"),
    ("Lookup Speed",        "Slow",      "Slow",      "Fast",            "Fast",             "Fast"),
    ("Stores",              "Elements",  "Elements",  "Unique elements", "Unique elements",  "Key-Value pairs"),
    ("Typical Use",         "Sequence",  "Fixed data","Unique items",    "Immutable set",    "Mapping/Lookup"),
]

for row in rows:
    print(f"{row[0]:<22}{row[1]:<12}{row[2]:<12}{row[3]:<12}{row[4]:<12}{row[5]:<12}")
# Out:
# Property              List        Tuple       Set         Frozenset   Dictionary
# ------------------------------------------------------------------------------------------
# Syntax                [ ]         ( )         { }         frozenset() { : }
# Ordered               Yes         Yes         No          No          Yes
# Mutable               Yes         No          Yes         No          Yes
# Allow Duplicates      Yes         Yes         No          No          No (keys)
# Indexed               Yes         Yes         No          No          No (key-based)
# Hetrogeneneous        Yes         Yes         Yes         Yes         Yes
# Hashable              No          Yes         No          Yes         No
# Can be dictionary key No          Yes         No          Yes         No
# Can be nested         Yes         Yes         No          No          Yes
# Supports slicing      Yes         Yes         No          No          No
# ...
